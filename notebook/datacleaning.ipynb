# %% [markdown]
# Data Cleaning and Preprocessing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# load data

# %%
df=pd.read_csv("../dataset/data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3764 entries, 0 to 3763
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   team            3764 non-null   object
#  1   opponent        3764 non-null   object
#  2   homePct(%)      3764 non-null   int64
#  3   awayPct(%)      3764 non-null   int64
#  4   awayShot        3764 non-null   int64
#  5   awayShotOnGoal  3764 non-null   int64
#  6   homeShot        3764 non-null   int64
#  7   homeShotOnGoal  3764 non-null   int64
#  8   goal            3764 non-null   int64
#  9   opGoal          3764 non-null   int64
#  10  session         3764 non-null   object
#  11  corner          3764 non-null   int64
#  12  opcorner        3764 non-null   int64
#  13  id              3764 non-null   int64
#  14  result          3764 non-null   int64
# dtypes: int64(12), object(3)
# memory usage: 441.2+ KB

# %% [markdown]
# Missing Values

# %%
df.isnull().sum()
# Out:
# team              0
# opponent          0
# homePct(%)        0
# awayPct(%)        0
# awayShot          0
# awayShotOnGoal    0
# homeShot          0
# homeShotOnGoal    0
# goal              0
# opGoal            0
# session           0
# corner            0
# opcorner          0
# id                0
# result            0
# dtype: int64

# %% [markdown]
# fill possesion =0 with mean

# %%
indexNZero = list(df[df['homePct(%)'] != 0].index)
mean = np.mean(list(df.iloc[indexNZero]['homePct(%)']))
df['homePct(%)'] = df['homePct(%)'].apply(lambda x: mean if x == 0 else x)
indexNZero = list(df[df['awayPct(%)'] != 0].index)
mean = np.mean(list(df.iloc[indexNZero]['awayPct(%)']))
df['awayPct(%)'] = df['awayPct(%)'].apply(lambda x: mean if x == 0 else x)

# %% [markdown]
# Remove data duplicates

# %%
df.drop_duplicates()
# Out:
#                         team           opponent  homePct(%)  awayPct(%)  \
# 0           Newcastle United            Everton        50.0        50.0
# 1             Wigan Athletic  Manchester United        53.0        47.0
# 2                Southampton            Arsenal        44.0        56.0
# 3                  Liverpool         Sunderland        66.0        34.0
# 4                    Chelsea        Southampton        58.0        42.0
# ...                      ...                ...         ...         ...
# 3759  Brighton & Hove Albion            Arsenal        68.0        32.0
# 3760         Manchester City            Everton        74.0        26.0
# 3761                  Fulham        Southampton        62.0        38.0
# 3762        Newcastle United       Leeds United        59.0        41.0
# 3763         AFC Bournemouth     Crystal Palace        59.0        41.0
#
#       awayShot  awayShotOnGoal  homeShot  homeShotOnGoal  goal  opGoal  \
# ...

# %% [markdown]
# write cleaned file

# %%
df.to_csv("../dataset/cleaned_data.csv", index=False)
